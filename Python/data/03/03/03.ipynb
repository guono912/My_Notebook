# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Anscombe-四重奏" data-toc-modified-id="Anscombe-四重奏-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Anscombe 四重奏</a></span></li><li><span><a href="#Matplotlib-&amp;-Seaborn" data-toc-modified-id="Matplotlib-&amp;-Seaborn-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Matplotlib &amp; Seaborn</a></span><ul class="toc-item"><li><span><a href="#数据准备" data-toc-modified-id="数据准备-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>数据准备</a></span></li><li><span><a href="#散点图" data-toc-modified-id="散点图-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>散点图</a></span></li><li><span><a href="#直方图" data-toc-modified-id="直方图-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>直方图</a></span></li><li><span><a href="#盒图" data-toc-modified-id="盒图-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>盒图</a></span></li><li><span><a href="#柱状图" data-toc-modified-id="柱状图-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>柱状图</a></span></li><li><span><a href="#小提琴图" data-toc-modified-id="小提琴图-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>小提琴图</a></span></li><li><span><a href="#点对图" data-toc-modified-id="点对图-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>点对图</a></span></li><li><span><a href="#热力图" data-toc-modified-id="热力图-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>热力图</a></span></li><li><span><a href="#饼图" data-toc-modified-id="饼图-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>饼图</a></span></li></ul></li><li><span><a href="#词云" data-toc-modified-id="词云-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>词云</a></span><ul class="toc-item"><li><span><a href="#矩形词云" data-toc-modified-id="矩形词云-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>矩形词云</a></span></li><li><span><a href="#个性化词云" data-toc-modified-id="个性化词云-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>个性化词云</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Anscombe 四重奏

# %% [markdown]
# 观察下面四组数据
#
# ||Set I||Set II ||Set III||Set IV|
# |:-|:-|:-|:-|:-|:-|:-|:-|
# |	x	|	y	|	x	|	y	|	x	|	y	|	x	|	y	|
# |	10	|	8.04	|	10	|	9.14	|	10	|	7.46	|	8	|	6.58	|
# |	8	|	6.95	|	8	|	8.14	|	8	|	6.77	|	8	|	5.76	|
# |	13	|	7.58	|	13	|	8.74	|	13	|	12.74	|	8	|	7.71	|
# |	9	|	8.81	|	9	|	8.77	|	9	|	7.11	|	8	|	8.84	|
# |	11	|	8.33	|	11	|	9.26	|	11	|	7.81	|	8	|	8.47	|
# |	14	|	9.96	|	14	|	8.1	|	14	|	8.84	|	8	|	7.04	|
# |	6	|	7.24	|	6	|	6.13	|	6	|	6.08	|	8	|	5.25	|
# |	4	|	4.26	|	4	|	3.1	|	4	|	5.39	|	19	|	12.5	|
# |	12	|	10.84	|	12	|	9.13	|	12	|	8.15	|	8	|	5.56	|
# |	7	|	4.82	|	7	|	7.26	|	7	|	6.42	|	8	|	7.91	|
# |	5	|	5.68	|	5	|	4.74	|	5	|	5.73	|	8	|	6.89	|
#
# 是否发现什么规律？

# %%
# 加载模块
import seaborn as sns  # Visualization
import pandas as pd  # Data manipulation
import matplotlib.pyplot as plt  # Plots
from scipy import stats # Linear regression 
import numpy as np  # Fundamental package for scientific computing

anscombe = sns.load_dataset("anscombe")

# %%
# 数据类型
type(anscombe)
# Out:
# pandas.core.frame.DataFrame

# %%
# 查看数据
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# 数据统计
anscombe.groupby("dataset").describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
# 线性回归结果
for data_set in anscombe.dataset.unique():
    df = anscombe.query("dataset == '{}'".format(data_set)) 
    slope, intercept, r_val, p_val, slope_std_error = stats.linregress(x=df.x, y=df.y) 
    print("Data set {:<5}: y={:.2f}x+{:.2f} (p: {:.4f}, R^2: {:.4f})".format(data_set, slope, intercept, p_val, r_val))
# Out:
# Data set I    : y=0.50x+3.00 (p: 0.0022, R^2: 0.8164)
# Data set II   : y=0.50x+3.00 (p: 0.0022, R^2: 0.8162)
# Data set III  : y=0.50x+3.00 (p: 0.0022, R^2: 0.8163)
# Data set IV   : y=0.50x+3.00 (p: 0.0022, R^2: 0.8165)

# %%
# 绘制线性回归
sns.lmplot(x="x", y="y",col="dataset",hue="dataset",col_wrap=2,data=anscombe,markers='o',size=5,scatter_kws={"s": 100});

# %%
# 绘制线性回归
sns.lmplot(x="x", y="y",hue="dataset",data=anscombe,markers=['s','x','^','o'],size=6,scatter_kws={"s": 100});

# %% [markdown]
# # Matplotlib & Seaborn

# %%
import matplotlib.pyplot as plt
# 使用内嵌模式画图
#%matplotlib notebook
# %matplotlib inline
from pylab import mpl
# mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.sans-serif'] = ['STHeiti']

# %% [markdown]
# ## 数据准备
# 首先我们可以使用pandas将数据文件读取，数据类型为DataFrame。

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
boston = pd.read_csv("./boston_house_prices.csv")

# %%
boston.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# ## 散点图
# 散点图能够同时将两个数值型特征可视化，从散点图中我们可以直观地观察两个特征之间的关系。例如是否存在线性关系等。
# seaborn中可以使用 `jointplot` 函数绘制散点图。`jointplot` 函数通常由三个参数需要设置，x和y分别代表需要横轴和纵轴显示的特征名称。data为数据，可以为DataFrame类型。例如在房价数据中，我们需要绘制犯罪率(CRIM)与房价(MEDV)之间的散点图，可以使用以下代码：

# %%
sns.set()
sns.jointplot(x="CRIM" , y = "MEDV" ,data = boston)

# %% [markdown]
# 从上图可以发现，我们不仅得到了两个特征的散点图，对于每一个单独的特征，`jointplot`函数默认将其直方图进行了绘制。同时，也将特征之间的皮尔逊相关系数计算出来。皮尔逊相关系数能够用来判断特征之间的线性关系，其取值范围为[-1,1]。取值为0表示两个特征没有相关性。越接近1说明特征之间越存在正相关性。越接近-1表示特征之间越存在负的线性相关性。在我们的上述例子中，皮尔逊相关系数为-0.39,说明犯罪率与房价之间存在一定的负相关性。

# %% [markdown]
# ## 直方图
# 对于连续型特征，我们可以使用直方图来观察特征取值的分布情况。在seaborn中，直方图可以使用 `distplot` 函数进行绘制。例如，我们绘制出单位财产税(TAX)特征的直方图。

# %%
sns.distplot(boston["TAX"],bins = 10,kde = True)

# %% [markdown]
# `distplot` 函数默认同时绘制直方图和KDE(核密度图),如果不需要核密度图，可以将kde参数设置成False。

# %% [markdown]
# ## 盒图
# 盒图可以直观地将连续型特征的中位数、上下四分位数显示出来。通常也作为一种单特征离群值检测的定性方法。在seaborn中，可以使用 `boxplot` 函数绘制盒图。参数orient设置盒图的朝向。

# %%
sns.boxplot(boston["MEDV"],orient = "h")

# %% [markdown]
# 我们可以先对数据进行分组，然后对比不同组数据的分布（盒图表示）。我们只需要给 `boxplot` 函数制定x和y两个参数。其中，x为分组特征，需要为离散型。y为对比的特征。例如我们查看不同的房间数下，房价的分布情况，可以使用以下代码：

# %%
import math
boston["RM_int"] = boston["RM"].map(math.floor) #因为RM原始为连续型特征，首先对其取整
sns.boxplot(x="RM_int", y = "MEDV",data = boston, orient="v")

# %% [markdown]
# 通过上图可以看出，随着房间数目的增大，房价呈现先下降后上升的变化趋势。

# %% [markdown]
# 进一步地，我们可以通过hue参数制定第二个分组特征。例如我们希望进一步观察房子是否在河边(CHAS)对房价的影响。

# %%
sns.boxplot(x="RM_int", y = "MEDV", hue = "CHAS",data = boston, orient="v")

# %% [markdown]
# 通过上述盒图，我们可以得出两个基本观察结论
# + 房间数小于5的房子都不在河边
# + 在房间数量相同的情况下，河边的房子比非河边的房子价格要高。
#
# 以上两点与我们日常生活经验也是相符合的。

# %% [markdown]
# ## 柱状图
# 对于离散型特征，我们可以使用柱状图绘制其每一种取值的样本数量。例如，对于房间数（RM_int），可以通过seaborn的 `countplot` 函数画出不同房间数量的房子的数量。

# %%
sns.countplot(x = "RM_int", data = boston)

# %% [markdown]
# 同样地，我们可以进一步制定一个分组特征绘制不同分组下的柱状图。

# %%
sns.countplot(x = "RM_int", hue = "CHAS", data = boston)

# %% [markdown]
# ## 小提琴图
# 核密度图是一种结合了盒图和核密度图的图。它将盒图和密度图展示在同一个图上，因长相通常类似小提琴而得名。在seaborn中，可以使用 `violinplot` 函数绘制小提琴图。

# %%
sns.violinplot(x="RM_int", y = "MEDV",data = boston)

# %% [markdown]
# 与盒图类似，我们可以在小提琴图中制定额外的分组特征。

# %%
sns.violinplot(x="RM_int", y = "MEDV", hue = "CHAS",data = boston, orient="v")

# %% [markdown]
# 将上图的分组分别绘制在盒图的两边， 使用split=True参数设置。

# %%
sns.violinplot(x="RM_int", y = "MEDV", hue = "CHAS",split = True, data = boston)

# %% [markdown]
# ## 点对图
# 点对图可以同时将多个特征两两之间的散点图等通过一条命令进行绘制。点对图的绘制函数为 `pairplot`。为了显示美观，我们只选取数据找那个特征的一个子集进行绘制。

# %%
sns.pairplot(boston[["CRIM","NOX","RM","LSTAT","MEDV"]])

# %% [markdown]
# ## 热力图
# 通过热力图我们可以直观地观察特征之间的相关性强弱。

# %%
import matplotlib.pyplot as plt
corr = boston.corr()#特征的相关系数矩阵
f, ax = plt.subplots(figsize=(10, 10))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, cmap=cmap, vmax=1.0,
            square=True, xticklabels=2, yticklabels=2,
            linewidths=.3, cbar_kws={"shrink": .5}, ax=ax)
plt.show()

# %% [markdown]
# ## 饼图

# %%
import numpy as np
import pandas as pd

# %%
# 读取数据
df = pd.read_csv('name_data.csv', header=0,encoding='utf-8')

# %%
# 数据统计
df['area_name'].value_counts()
# Out:
# 长春    4085
# 四平    1199
# 吉林    1146
# 松原     739
# 通化     729
# 白城     673
# 延边     638
# 白山     483
# 辽源     308
# Name: area_name, dtype: int64

# %%
# Counts list
x = df['area_name'].value_counts().tolist()

# %%
from pylab import mpl
from matplotlib.font_manager import _rebuild
_rebuild()
mpl.rcParams['font.sans-serif']=[u'SimHei'] # 中文字体
mpl.rcParams['axes.unicode_minus']=False
lbls = [u'长春',u'四平',u'吉林',u'松原',u'通化',u'白城',u'延边',u'白山',u'辽源']
epd = [0.05, 0, 0.1, 0, 0.1, 0, 0.2, 0.1, 0] # 分离程度
plt.figure(figsize=(6,6))
plt.pie(x,labels = lbls,explode=epd,autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # 词云

# %%
# 加载词云包 wordcloud, jieba
from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator
import codecs
import jieba

# %%
df['city_name'].value_counts()
# Out:
# 长春市    3144
# 吉林市     844
# 松原市     573
# 四平市     488
# 通化市     305
# 榆树      279
# 延吉市     267
# 公主岭     253
# 农安      245
# 白城市     236
# 伊通      212
# 德惠      180
# 梨树      177
# 白山市     162
# 九台      156
# 辽源市     153
# 梅河口     151
# 洮南      128
# 敦化      121
# 通榆      121
# 柳河      105
# 东丰       96
# 大安       95
# 镇赉       93
# 双阳       81
# 抚松       80
# 蛟河       73
# 双辽       69
# 江源       66
# 靖宇       65
# 通化县      65
# 临江       63
# 长岭       63
# 舒兰       62
# 桦甸       62
# 汪清       62
# 磐石       59
# 东辽       59
# 辉南       58
# 乾安       56
# 珲春市      52
# 长白       47
# 扶余       47
# 永吉       46
# 集安       45
# 和龙       42
# 安图       40
# 图们       36
# 龙井       18
# Name: city_name, dtype: int64

# %%
city_name = df['city_name'].to_string()

# %%
# jieba 分词处理
wordlist_after_jieba = jieba.cut(city_name, cut_all = True)
wl_space_split = " ".join(wordlist_after_jieba)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/zx/zt997fcn31qf9zktb4m6dh280000gp/T/jieba.cache
# Loading model cost 1.876 seconds.
# Prefix dict has been built succesfully.

# %% [markdown]
# ## 矩形词云

# %%
# 生成一般矩形词云
city_name_wordcloud = WordCloud(font_path = 'simhei.ttf').generate(wl_space_split)
plt.figure()
plt.imshow(city_name_wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ## 个性化词云
# 可以使用对比度较强的任意背景图片生成词云

# %%
# 读取背景图片
backgroud_Image = plt.imread('tree.jpg')

# %%
# 生成词云
wc = WordCloud( background_color = 'white',    # 设置背景颜色
                mask = backgroud_Image,        # 设置背景图片
                max_words = 10000,            # 设置最大现实的字数
                stopwords = STOPWORDS,        # 设置停用词
                font_path = 'simhei.ttf',# 设置字体格式，如不设置显示不了中文
                max_font_size = 150,            # 设置字体最大值
                random_state = 1,            # 设置有多少种随机生成状态，即有多少种配色方案
                )
city_name_wordcloud = wc.generate(wl_space_split)



plt.figure()
plt.imshow(backgroud_Image)
plt.axis('off') 
plt.show()
plt.figure()
plt.imshow(city_name_wordcloud)
plt.axis("off")
plt.show()
